# %%
# Function definition
def welcome_student(name):
    return "Welcome, " + name + "! Have a great learning journey."

# Get input from the user
student_name = input("Enter the student's name: ")

# Call the function
message = welcome_student(student_name)

# Print the returned message
print(message)
# Out:
# Welcome, Gurumahesh k! Have a great learning journey.

# %%
# addition of two numbers
def add_numbers(c):
    return "sum of two numbers",x

number1 = int(input("Enter 1st number: "))
number2 = int(input("Enter 2nd number: "))
x = number1 + number2

print(add_numbers(x))
# Out:
# ('sum of two numbers', 100)

# %%
#  addition
def add(a, b):
    return a + b

#  subtraction
def subtract(a, b):
    return a - b

#  multiplication
def multiply(a, b):
    return a * b

#  division
def divide(a, b):
    if b == 0:
        return "Error! Division by zero is not allowed."
    return a / b


# Accept two numbers from the user
num1 = float(input("Enter the first number: "))
num2 = float(input("Enter the second number: "))

print("\nSelect an operation:")
print("Enter (1) Addition (+)")
print("Enter (2)Subtraction (-)")
print("Enter (3)Multiplication (*)")
print("Enter (4)Division (/)")



choice = input("Enter your choice (1/2/3/4): ")

# Call the appropriate function
if choice == "1":
    result = add(num1, num2)
    print("Result =", result)

elif choice == "2":
    result = subtract(num1, num2)
    print("Result =", result)

elif choice == "3":
    result = multiply(num1, num2)
    print("Result =", result)

elif choice == "4":
    result = divide(num1, num2)
    print("Result =", result)

else:
    print("Invalid choice! Please select a valid operation.")
# Out:
# Select an operation:
# Enter (1) Addition (+)
# Enter (2)Subtraction (-)
# Enter (3)Multiplication (*)
# Enter (4)Division (/)
# Result = 78400000000.0

# %%
def check_even_odd(number): #checking even or odd
    if number % 2 == 0:
        return number," is even"
    elif number % 2 == 1:
        return number,"is odd"
    else:
       return "Enter a valid number"
number = int(input("Enter a number: "))  

print(check_even_odd(number))
# Out:
# (8, ' is even')

# %%
def find_largest(number1, number2,number3): #find largest number
    if number1 >= number2 and number1 >= number3:
        return number1,"is largest number"
    elif number2 >= number1 and number2 >= number3:
        return number2,"is largest number"
    else:
        return number3,"is largest number"
number1 = int(input("Enter a first number: "))
number2 = int(input("Enter a second number: "))
number3 = int(input("Enter a third number: "))

print(find_largest(number1, number2,number3))
# Out:
# (3, 'is largest number')

# %%
def calculate_square(number): #find square and cube of number
    square = number ** 2
    return "square :",square


def calculate_cube(number):
    cube = number ** 3
    return "cube :",cube

number = int(input("Enter a number: "))
print(calculate_square(number))
print(calculate_cube(number))
# Out:
# ('square :', 16)
# ('cube :', 64)

# %%
def rectangle_area(Length,width):

  if Length> 0 and width > 0:
    area = Length * width
    return "Area of Rectangle is: ",area
  else:
    return "Enter only positive number"
     

Length = int(input("Enter length: "))
width = int(input("Enter width: "))


print(rectangle_area(Length,width))
# Out:
# ('Area of Rectangle is: ', 20)

# %%
import math
def circle_area(radius):
    x = math.pi * radius ** 2
    return "Area of the circle: ",x
def circle_circumference(radius):
    y = 2 * math.pi

    return "Cicumference of the circle: ",y
radius = int(input("Enter radius"))

print(circle_area(radius))
print(circle_circumference(radius))
# Out:
# ('Area of the circle: ', 113.09733552923255)
# ('Cicumference of the circle: ', 6.283185307179586)

# %%
def calculate_grade(marks):
    if marks < 0 or marks > 100:
        return "Enter valid marks"
    elif marks >= 90:
        return "Grade: A"
    elif marks >=80:
        return "Grade: B"
    elif marks >=70:
        return "Grade: C"
    elif marks >=60:
        return "Grade: D"
    
    else:
        return "Grade: F"
marks = int(input("Enter Marks: "))
print(calculate_grade(marks))
# Out:
# Grade: A

# %%
def sample_interest(Principal,rate,time):
    Interest = (Principal * rate * time) / 100
    return "Sample interest: ",Interest
Principal = int(input("Principal: "))
rate = int(input("Rate: ")) 
time = int(input("time: "))
print(sample_interest(Principal,rate,time))
# Out:
# ('Sample interest: ', 18000.0)

# %%
#to convert celsius to fahrenheit
def celsius_to_fahrenheit(Celsius):
    Fahrenheit = (Celsius * 9/5) + 32
    return f"Temperature in Fahrenheit: {Fahrenheit:.2f}°F"

Celsius = float(input("Enter Temperature in Celsius: "))
print(celsius_to_fahrenheit(Celsius))
# Out:
# Temperature in Fahrenheit: 77.00°F

# %%
#to find leap year
def is_leap_year(year):
    if (year % 400 == 0) or (year % 4 == 0 and year % 100 != 0):
        return True
    else:
        return False

year = int(input("Enter a year: "))

if is_leap_year(year):
    print(year, "is a leap year.")
else:
    print(year, "is not a leap year.")
# Out:
# 2020 is a leap year.

# %%
#to find factorial of a number
def calculate_factorial(number):
    if number < 0:
        return "Factorial is not defined for negative numbers."

    factorial = 1

    for i in range(1, number + 1):
        factorial = factorial * i

    return factorial
number = int(input("Enter a non-negative integer: "))


result = calculate_factorial(number)
print(result)
# Out:
# 362880

# %%
def multiplication_table(number,limit):
    

    for i in range(1,limit+1):
        print(f"{number} x {i} = {number * i}")
limit = 10
number = int(input("Enter a number: "))
print("Defalut limit = 10",multiplication_table(number,limit),)  

custom_limit = int(input("Enter custom limit: "))
print("custom limit",multiplication_table(number,custom_limit))
# Out:
# 2 x 1 = 2
# 2 x 2 = 4
# 2 x 3 = 6
# 2 x 4 = 8
# 2 x 5 = 10
# 2 x 6 = 12
# 2 x 7 = 14
# 2 x 8 = 16
# 2 x 9 = 18
# 2 x 10 = 20
# Defalut limit = 10 None
# 2 x 1 = 2
# 2 x 2 = 4
# 2 x 3 = 6
# 2 x 4 = 8
# 2 x 5 = 10
# 2 x 6 = 12
# 2 x 7 = 14
# 2 x 8 = 16
# 2 x 9 = 18
# 2 x 10 = 20
# 2 x 11 = 22
# 2 x 12 = 24
# custom limit None

# %%
#find vowels in a string
def count_vowels(text):
    vowels = "AEIOUaeiou"
    count = 0

    for char in text:
        if char in vowels:
            count += 1

    return count


text = input("Enter a string: ")

print("Total vowels:", count_vowels(text))
# Out:
# Total vowels: 4

# %%
# reverse a string
def reverse_string(text):
    return text[::-1]

text = input("Enter a string: ")

print("Reversed string:", reverse_string(text))
# Out:
# Reversed string: nrocirpaC

# %%
#palindrome or not
def is_palindrome(text):
    text = text.replace(" ", "").lower()
    return text == text[::-1]
text = input("Enter a string")

if is_palindrome(text):
    print(f'"{text}" is a palindrome.')
else:
    print(f'"{text}" is not a palindrome.')
# Out:
# "never even or odd" is not a palindrome.

# %%
# calculate list sum of numbers
def calculate_list_sum(numbers):
    total = 0
    for number in numbers:
        total += number
    return total

numbers = list(map(int, input("Enter numbers separated by spaces: ").split()))

result = calculate_list_sum(numbers)
print("Sum of the list:", result)
# Out:
# Sum of the list: 100
